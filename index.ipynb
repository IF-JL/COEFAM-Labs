# %% [markdown]
# # Smart Manufacturing — Lab Hub
# **IntelleX Fabrica · Training Systems Division**
#
# This is the launch page for all course labs. Each lab is a Jupyter notebook that runs free in Google Colab — students click **Open in Colab**, then **File → Save a copy in Drive** to get their own copy.
#
# **How to use this hub**
# 1. Set your GitHub username + repo in the first code cell below.
# 2. Run both code cells.
# 3. Share *this* notebook's Colab link with students — it is their table of contents.

# %% [markdown]
# ### 1 · Point the hub at your repo

# %%
# ==== Repo this hub points at (already set) ====
GH_USER = "IF-JL"          # GitHub username
GH_REPO = "COEFAM-Labs"    # repo name
BRANCH  = "main"

# %% [markdown]
# ### 2 · Render the lab catalog

# %%
from IPython.display import HTML, display

# ── To add a lab: add one row here and drop its .ipynb in the matching labs/ folder ──
# (cert_group, title, repo_path, what_youll_do, status)   status: "ready" | "soon"
CATALOG = [
    ("Cert 02 · Integrated Systems",
     "i3-X API — Query a Live Smart-Manufacturing Server",
     "labs/cert03_auto_id/i3x_api_intro.ipynb",
     "Call the public i3-X demo API and read equipment, attributes and live values back over one standard interface. No install, no login.",
     "ready"),

    ("Cert 03 · Automatic Identification",
     "OPC UA Machinery — Read a Machine's Identity (Nameplate)",
     "labs/cert03_auto_id/opcua_machinery_identity.ipynb",
     "Connect to an OPC UA server and read the Machinery Identification profile — make, model, serial, capabilities — i.e. a machine identifying itself.",
     "ready"),
    ("Cert 03 · Automatic Identification",
     "OPC UA Robotics — Explore a Robot Companion Spec",
     "labs/cert03_auto_id/opcua_robotics_explore.ipynb",
     "Browse the Robotics NodeSet and pull identity + status values from a running robotics server.",
     "soon"),

    ("Cert 04 · Data Analytics",
     "1 · Intro to Manufacturing Data (pandas)",
     "labs/cert04_data_analytics/data_1_intro_pandas.ipynb",
     "Load a real-shaped factory production log, explore it, filter rows, and group/aggregate — the core pandas moves — to find the problem machine.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "2 · Visualizing Process Data (matplotlib)",
     "labs/cert04_data_analytics/data_2_visualizing.ipynb",
     "The four charts every analyst needs: a process trend line, a distribution histogram, a category bar chart, and a box plot by machine.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "3 · Descriptive Stats & Process Stability",
     "labs/cert04_data_analytics/data_3_stats_stability.ipynb",
     "Mean/std/quartiles, mean ±3σ control limits, flagging out-of-control readings, and a rolling-mean control chart.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "4 · Correlation & Root-Cause Analysis",
     "labs/cert04_data_analytics/data_4_correlation.ipynb",
     "Scatter plots, a correlation matrix, and fail-rate-by-temperature-band to find what actually drives the defects.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "5 · Calculating OEE from a Production Log",
     "labs/cert04_data_analytics/data_5_oee.ipynb",
     "Merge two tables, aggregate counts, and compute Availability × Performance × Quality = OEE — then rank the machines.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "6 · Comparing Shifts & Trends Over Time",
     "labs/cert04_data_analytics/data_6_timeseries.ipynb",
     "Work with timestamps: compare Day vs Night, chart daily trends and throughput, and find the hour-of-day pattern.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "7 · Predicting Failures (scikit-learn)",
     "labs/cert04_data_analytics/data_7_predict.ipynb",
     "Train a classifier to predict pass/fail from process values — with the imbalanced-data accuracy trap, precision/recall, and feature importance. Predictive analytics.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "8 · Quality & SPC — Control Charts & Cpk",
     "labs/cert04_data_analytics/data_8_spc.ipynb",
     "Statistical process control: individuals and X-bar control charts, out-of-control signals, and Cp/Cpk process capability against spec limits.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "Signal Filtering 1 · See & Quantify the Noise",
     "labs/cert04_data_analytics/nf_1_see_noise.ipynb",
     "Load a noisy weight-sensor signal, plot it, find the quantization step, measure at-rest noise, and read the residual power spectrum to see what kind of noise it is.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "Signal Filtering 2 · Basic Smoothing (moving avg / EWMA / median)",
     "labs/cert04_data_analytics/nf_2_smoothing.ipynb",
     "The three everyday smoothers, the window/span/kernel trade-off, and why a median filter rejects spikes that a moving average smears.",
     "ready"),
    ("Cert 04 · Data Analytics",
     "Signal Filtering 3 · Frequency-Domain & Shape (Butterworth / Savitzky-Golay)",
     "labs/cert04_data_analytics/nf_3_frequency.ipynb",
     "Zero-phase Butterworth low-pass, shape-preserving Savitzky-Golay, and a median-then-Butterworth composite — the load-cell engineer's toolkit.",
     "ready"),

    ("Cert 04 · Data Analytics",
     "Images as Data — ROI to Average Color",
     "labs/cert04_data_analytics/roi_average_color.ipynb",
     "Turn an image into a feature vector: pick a Region of Interest, average its pixels, and read a part's color as data — the first step of vision analytics.",
     "ready"),

]

# order the certificate groups
GROUP_ORDER = [
    "Cert 01 · Intro to Smart Mfg & IIoT",
    "Cert 02 · Integrated Systems",
    "Cert 03 · Automatic Identification",
    "Cert 04 · Data Analytics",
    "Cert 05 · Smart Factory Systems",
]

BADGE = "https://colab.research.google.com/assets/colab-badge.svg"
def colab_url(path):
    return f"https://colab.research.google.com/github/{GH_USER}/{GH_REPO}/blob/{BRANCH}/{path}"

# ---- brand-ish palette ----
P = dict(bg="#0d1628", panel="#121a2e", border="#2a3350", text="#e8e0f5",
         mid="#a9a2c4", purple="#6666ff", orange="#f98513", green="#3de080", faint="#6b7392")

groups = {}
for row in CATALOG:
    groups.setdefault(row[0], []).append(row)

html = [f'''<div style="font-family:Inter,Arial,sans-serif;background:{P['bg']};color:{P['text']};
padding:22px 24px;border:1px solid {P['border']};border-radius:10px;max-width:900px">
<div style="font-family:Rajdhani,Arial;font-size:26px;font-weight:700;letter-spacing:-.3px">
Intellex<span style="color:{P['purple']}">Fabrica</span>
<span style="color:{P['mid']};font-size:15px;font-weight:400"> · Smart Manufacturing Lab Hub</span></div>
<div style="color:{P['mid']};font-size:13px;margin:6px 0 4px">
Click <b style="color:{P['orange']}">Open in Colab</b> on any ready lab. In Colab: <i>File → Save a copy in Drive</i> to get your own runnable copy.</div>''']

order = [g for g in GROUP_ORDER if g in groups] + [g for g in groups if g not in GROUP_ORDER]
for g in order:
    html.append(f'<div style="margin-top:18px;font-family:Rajdhani,Arial;font-weight:700;font-size:11px;'
                f'letter-spacing:2px;text-transform:uppercase;color:{P["orange"]};border-bottom:1px solid {P["border"]};padding-bottom:6px">{g}</div>')
    for _, title, path, desc, status in groups[g]:
        if status == "ready":
            action = f'<a href="{colab_url(path)}" target="_blank"><img src="{BADGE}" alt="Open in Colab"></a>'
            dot = P["green"]
        else:
            action = f'<span style="font-family:Inter;font-size:11px;color:{P["faint"]};border:1px solid {P["border"]};border-radius:20px;padding:3px 10px">soon</span>'
            dot = P["faint"]
        html.append(f'''<div style="display:flex;gap:14px;align-items:flex-start;padding:12px 2px;border-bottom:1px solid {P['border']}">
<div style="width:8px;height:8px;border-radius:50%;background:{dot};margin-top:6px;flex-shrink:0"></div>
<div style="flex:1;min-width:0">
<div style="font-size:14px;font-weight:600">{title}</div>
<div style="color:{P['mid']};font-size:12.5px;line-height:1.5;margin-top:2px">{desc}</div></div>
<div style="flex-shrink:0;align-self:center">{action}</div></div>''')

html.append('</div>')
display(HTML("".join(html)))

# %% [markdown]
# ---
# ### Adding a new lab (repeatable)
# 1. Put the notebook in the right folder under `labs/` (one folder per certificate).
# 2. Add one row to `CATALOG` above: `(cert_group, title, repo_path, description, "ready")`.
# 3. Commit & push. Re-run the catalog cell — the new lab appears with its own **Open in Colab** button.
#
# Rows marked `"soon"` show a greyed *soon* chip instead of a button — use them to publish the roadmap before a lab is finished.
