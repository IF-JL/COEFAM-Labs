# %% [markdown]
# # Lab NN — <Lab Title>
# **Certificate 0X · <Module>**  |  [← Back to the Lab Hub](../../index.ipynb)
#
# _One-sentence description of what this lab does._

# %% [markdown]
# ## Objectives
# By the end of this lab you will be able to:
# - …
# - …

# %% [markdown]
# ## Setup
# Run this cell first. (Colab has `requests`, `pandas`, `numpy`, `matplotlib` preinstalled — only add what is missing.)

# %%
# !pip install asyncua paho-mqtt   # uncomment if the lab needs extra packages
import requests, json

# %% [markdown]
# ## Steps

# %%
# Step 1 — …

# %% [markdown]
# ## Debrief
# - What did you observe?
# - Where would this fit in a real plant?
